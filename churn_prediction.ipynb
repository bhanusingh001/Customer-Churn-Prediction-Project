# %%
import pandas as pd

# %%
# !pip install xgboost
# Out:
# ...
#   Using cached xgboost-3.1.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#     --------------------------------------- 1.0/72.0 MB 6.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.8/72.0 MB 5.3 MB/s eta 0:00:14
#    - -------------------------------------- 3.1/72.0 MB 5.4 MB/s eta 0:00:13
#    - -------------------------------------- 3.1/72.0 MB 5.4 MB/s eta 0:00:13
#    - -------------------------------------- 3.1/72.0 MB 5.4 MB/s eta 0:00:13
#    - -------------------------------------- 3.1/72.0 MB 5.4 MB/s eta 0:00:13
#    - -------------------------------------- 3.1/72.0 MB 5.4 MB/s eta 0:00:13
#    - -------------------------------------- 3.1/72.0 MB 5.4 MB/s eta 0:00:13
#    - -------------------------------------- 3.1/72.0 MB 5.4 MB/s eta 0:00:13
#    - -------------------------------------- 3.1/72.0 MB 5.4 MB/s eta 0:00:13
# ...

# %%
from pycaret.datasets import get_data
import pandas as pd

df = get_data('juice')   # Built-in churn dataset
df.head()
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %%
# Convert TotalCharges to numeric
from pycaret.datasets import get_data
df = get_data('juice')
df.head()
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %%
from pycaret.classification import *

exp = setup(data=df,
            target='Purchase',
            session_id=123,
            normalize=True,
            train_size=0.8,
            fold=5)
# Out:
# <style type="text/css">
# #T_6f219_row10_col1, #T_6f219_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6f219">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f219_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6f219_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f219_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f219_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6f219_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_6f219_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f219_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6f219_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_6f219_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model
# Out:
# <style type="text/css">
# #T_0bd26 th {
#   text-align: left;
# }
# ...

# %%
model = create_model('xgboost')
tuned_model = tune_model(model)

# %%
evaluate_model(tuned_model)

# %%
save_model(tuned_model, 'churn_model_pycaret')
loaded_model = load_model('churn_model_pycaret')
predict_model(loaded_model, data=df)
df_pred = predict_model(tuned_model, data=df)
df_pred[['Churn', 'prediction_label', 'prediction_score']].head()
